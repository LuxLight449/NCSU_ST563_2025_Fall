# %%
# !pip install numpy pandas scikit-learn


import numpy as np, pandas as pd, sklearn
print(np.__version__, pd.__version__, sklearn.__version__)
# Out:
# ...
# 1.26.4 2.2.2 1.5.2

# %% [markdown]
# # Ponder using Chatgpt

# %% [markdown]
# During the learning process, excessive reliance on AI tools like ChatGPT may lead to some ethical and learning-related issues.
#
# Firstly, it may weaken one's critical thinking ability. When facing problems, if we habitually seek answers directly from ChatGPT instead of first thinking, analyzing, and trying ourselves, we will gradually lose the ability to solve problems independently.
#
# Secondly, it may affect intellectual independence. The essence of learning is not only to obtain answers, but also to cultivate logical reasoning, problem decomposition, and autonomous exploration skills. If every step relies on AI providing ready-made solutions, the growth of one's knowledge system and experience accumulation will be limited.
#
# Finally, this will also raise ethical concerns regarding academic integrity. If students submit the content generated by AI directly as their own work, without digesting, understanding, and re-creating it, they will violate academic norms and even may constitute plagiarism.

# %% [markdown]
# I, Haozhe (Ray) Cui, pledge that I will always clearly specify the use of generative AI tools like ChatGPT for whatever purpose, and ensure that whatever I write in my report and code consists only of the things I have digested and actually understand. I promise that I will not copy and paste (even manually, by hand) from generative AI tools, and I will maintain a high work ethic in the reports I produce.I understand and agree that any discrepancy between my quiz performance and the quality of my homework, or between the quality of my midterm/final reports and my presentation and Q&A performance, can result in a significant reduction of my score. I pledge that I will not be a free rider in team projects but will faithfully contribute as a member by completing my portion.
